# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import math
from sklearn import preprocessing

# Set charts to view inline
# %matplotlib inline

# %%
df = pd.read_csv("fullsetmatrix1.csv")
x = df['1']
x
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4        529.41
# 5        529.46
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10       527.94
# 11       528.92
# 12          NaN
# 13          NaN
# 14          NaN
# 15       529.77
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22       527.52
# 23       526.32
# 24       525.04
# 25       525.70
# 26          NaN
# 27       525.74
# 28       525.72
# 29       525.59
#           ...
# 54023       NaN
# 54024       NaN
# 54025       NaN
# 54026       NaN
# 54027       NaN
# 54028    472.71
# 54029       NaN
# 54030       NaN
# 54031       NaN
# 54032       NaN
# 54033    475.01
# 54034       NaN
# 54035       NaN
# 54036       NaN
# 54037       NaN
# 54038    475.11
# 54039    475.91
# 54040    475.31
# 54041       NaN
# 54042    475.48
# 54043       NaN
# 54044       NaN
# 54045       NaN
# 54046    476.01
# ...

# %%
# Create x, where x the 'scores' column's values as floats
y = df[['1']].values.astype(float)

# Create a minimum and maximum processor object
min_max_scaler = preprocessing.MinMaxScaler()

# Create an object to transform the data to fit minmax processor
y_scaled = min_max_scaler.fit_transform(y)

# Run the normalizer on the dataframe
df_normalized1 = pd.DataFrame(y_scaled)
df_normalized1
# Out:
#               0
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4      0.483105
# 5      0.483304
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10     0.477268
# 11     0.481159
# 12          NaN
# 13          NaN
# 14          NaN
# 15     0.484534
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22     0.475601
# 23     0.470836
# 24     0.465753
# 25     0.468374
# 26          NaN
# 27     0.468533
# 28     0.468453
# 29     0.467937
# ...         ...
# 54023       NaN
# 54024       NaN
# 54025       NaN
# 54026       NaN
# 54027       NaN
# 54028  0.257971
# 54029       NaN
# 54030       NaN
# 54031       NaN
# 54032       NaN
# 54033  0.267103
# 54034       NaN
# 54035       NaN
# 54036       NaN
# 54037       NaN
# 54038  0.267500
# 54039  0.270677
# 54040  0.268295
# 54041       NaN
# 54042  0.268970
# 54043       NaN
# 54044       NaN
# 54045       NaN
# ...

# %%
# Create x, where x the 'scores' column's values as floats
z = df[['2']].values.astype(float)

# Create a minimum and maximum processor object
min_max_scaler = preprocessing.MinMaxScaler()

# Create an object to transform the data to fit minmax processor
z_scaled = min_max_scaler.fit_transform(z)

# Run the normalizer on the dataframe
df_normalized2 = pd.DataFrame(z_scaled)
df_normalized2
# Out:
#               0
# 0           NaN
# 1      0.337456
# 2      0.339015
# 3      0.337797
# 4      0.327781
# 5      0.330310
# 6      0.333607
# 7      0.328913
# 8      0.327137
# 9      0.326981
# 10     0.315708
# 11     0.321589
# 12     0.329006
# 13     0.328176
# 14     0.330194
# 15     0.330325
# 16     0.327191
# 17     0.332832
# 18     0.325771
# 19     0.322823
# 20     0.321286
# 21     0.320658
# 22     0.316204
# 23     0.297785
# 24     0.292121
# 25     0.307297
# 26     0.303930
# 27     0.302727
# 28     0.299150
# 29     0.296016
# ...         ...
# 54023  0.427327
# 54024  0.425123
# 54025  0.426124
# 54026  0.427094
# 54027  0.427133
# 54028  0.427133
# 54029  0.427878
# 54030  0.428258
# 54031  0.427955
# 54032  0.432448
# 54033  0.427924
# 54034  0.427924
# 54035  0.431478
# 54036  0.436133
# 54037  0.447453
# 54038  0.448819
# 54039  0.445040
# 54040  0.445048
# 54041  0.445048
# 54042  0.443512
# 54043  0.443519
# 54044       NaN
# 54045  0.447182
# ...

# %%
# Create x, where x the 'scores' column's values as floats
a = df[['3']].values.astype(float)

# Create a minimum and maximum processor object
min_max_scaler = preprocessing.MinMaxScaler()

# Create an object to transform the data to fit minmax processor
a_scaled = min_max_scaler.fit_transform(a)

# Run the normalizer on the dataframe
df_normalized3 = pd.DataFrame(a_scaled)
df_normalized3
# Out:
#               0
# 0      0.846244
# 1      0.847871
# 2      0.847936
# 3      0.851517
# 4      0.848718
# 5      0.847806
# 6      0.845202
# 7      0.847025
# 8           NaN
# 9           NaN
# 10     0.842599
# 11     0.843445
# 12     0.847025
# 13     0.848848
# 14     0.847416
# 15     0.852037
# 16     0.850280
# 17     0.853274
# 18          NaN
# 19     0.845853
# 20     0.850410
# 21     0.845398
# 22     0.840646
# 23     0.836480
# 24     0.828278
# 25     0.834657
# 26     0.837391
# 27     0.838953
# 28     0.836935
# 29     0.836024
# ...         ...
# 54023  0.440307
# 54024       NaN
# 54025  0.440307
# 54026  0.440307
# 54027       NaN
# 54028       NaN
# 54029       NaN
# 54030  0.445515
# 54031  0.445515
# 54032       NaN
# 54033  0.441870
# 54034       NaN
# 54035       NaN
# 54036  0.449421
# 54037  0.451959
# 54038  0.457818
# 54039  0.457818
# 54040  0.453326
# 54041  0.452220
# 54042  0.443562
# 54043  0.444994
# 54044  0.448119
# 54045  0.450983
# ...

# %%
# Create x, where x the 'scores' column's values as floats
b = df[['4']].values.astype(float)

# Create a minimum and maximum processor object
min_max_scaler = preprocessing.MinMaxScaler()

# Create an object to transform the data to fit minmax processor
b_scaled = min_max_scaler.fit_transform(b)

# Run the normalizer on the dataframe
df_normalized4 = pd.DataFrame(b_scaled)
df_normalized4
# Out:
#               0
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4      0.493034
# 5      0.493933
# 6      0.483146
# 7           NaN
# 8      0.491236
# 9           NaN
# 10     0.481798
# 11     0.483596
# 12          NaN
# 13     0.486292
# 14     0.483596
# 15     0.486742
# 16          NaN
# 17          NaN
# 18     0.483596
# 19     0.483146
# 20     0.482247
# 21     0.477303
# 22     0.476854
# 23     0.467865
# 24     0.464719
# 25     0.465618
# 26     0.466067
# 27     0.458876
# 28     0.461124
# 29     0.461124
# ...         ...
# 54023  0.498427
# 54024  0.498876
# 54025       NaN
# 54026  0.493483
# 54027       NaN
# 54028       NaN
# 54029       NaN
# 54030  0.499775
# 54031  0.503371
# 54032  0.506517
# 54033  0.506517
# 54034  0.506517
# 54035  0.506517
# 54036  0.511461
# 54037  0.513708
# 54038  0.512360
# 54039  0.515955
# 54040  0.515955
# 54041  0.515955
# 54042  0.517753
# 54043  0.518652
# 54044  0.520899
# 54045       NaN
# ...

# %%
# Create x, where x the 'scores' column's values as floats
c = df[['5']].values.astype(float)

# Create a minimum and maximum processor object
min_max_scaler = preprocessing.MinMaxScaler()

# Create an object to transform the data to fit minmax processor
c_scaled = min_max_scaler.fit_transform(c)

# Run the normalizer on the dataframe
df_normalized5 = pd.DataFrame(c_scaled)
df_normalized5
# Out:
#               0
# 0           NaN
# 1      0.074714
# 2      0.074734
# 3      0.073264
# 4      0.074734
# 5      0.074734
# 6      0.074734
# 7      0.076283
# 8      0.076204
# 9      0.076144
# 10     0.073066
# 11     0.073939
# 12     0.071953
# 13     0.071596
# 14     0.071616
# 15     0.072291
# 16     0.071993
# 17     0.072510
# 18     0.075052
# 19     0.070980
# 20     0.072688
# 21     0.072231
# 22     0.070921
# 23     0.069272
# 24     0.065499
# 25     0.068061
# 26     0.068696
# 27     0.068915
# 28     0.067505
# 29     0.070484
# ...         ...
# 54023  0.619221
# 54024  0.619221
# 54025  0.609926
# 54026  0.614434
# 54027  0.622637
# 54028  0.620214
# 54029  0.625993
# 54030  0.619558
# 54031  0.627165
# 54032  0.624345
# 54033  0.638147
# 54034  0.623232
# 54035  0.627741
# 54036  0.638346
# 54037  0.645039
# 54038  0.645039
# 54039  0.645933
# 54040  0.639240
# 54041  0.630481
# 54042  0.629190
# 54043  0.629270
# 54044  0.629528
# 54045  0.631296
# ...

# %%
result = pd.concat([df_normalized1, df_normalized2,df_normalized3,df_normalized4,df_normalized5], axis=1)
result
# Out:
#               0         0         0         0         0
# 0           NaN       NaN  0.846244       NaN       NaN
# 1           NaN  0.337456  0.847871       NaN  0.074714
# 2           NaN  0.339015  0.847936       NaN  0.074734
# 3           NaN  0.337797  0.851517       NaN  0.073264
# 4      0.483105  0.327781  0.848718  0.493034  0.074734
# 5      0.483304  0.330310  0.847806  0.493933  0.074734
# 6           NaN  0.333607  0.845202  0.483146  0.074734
# 7           NaN  0.328913  0.847025       NaN  0.076283
# 8           NaN  0.327137       NaN  0.491236  0.076204
# 9           NaN  0.326981       NaN       NaN  0.076144
# 10     0.477268  0.315708  0.842599  0.481798  0.073066
# 11     0.481159  0.321589  0.843445  0.483596  0.073939
# 12          NaN  0.329006  0.847025       NaN  0.071953
# 13          NaN  0.328176  0.848848  0.486292  0.071596
# 14          NaN  0.330194  0.847416  0.483596  0.071616
# 15     0.484534  0.330325  0.852037  0.486742  0.072291
# ...

# %%
result.columns = ['1', '2','3','4','5']
result
# Out:
#               1         2         3         4         5
# 0           NaN       NaN  0.846244       NaN       NaN
# 1           NaN  0.337456  0.847871       NaN  0.074714
# 2           NaN  0.339015  0.847936       NaN  0.074734
# 3           NaN  0.337797  0.851517       NaN  0.073264
# 4      0.483105  0.327781  0.848718  0.493034  0.074734
# 5      0.483304  0.330310  0.847806  0.493933  0.074734
# 6           NaN  0.333607  0.845202  0.483146  0.074734
# 7           NaN  0.328913  0.847025       NaN  0.076283
# 8           NaN  0.327137       NaN  0.491236  0.076204
# 9           NaN  0.326981       NaN       NaN  0.076144
# 10     0.477268  0.315708  0.842599  0.481798  0.073066
# 11     0.481159  0.321589  0.843445  0.483596  0.073939
# 12          NaN  0.329006  0.847025       NaN  0.071953
# 13          NaN  0.328176  0.848848  0.486292  0.071596
# 14          NaN  0.330194  0.847416  0.483596  0.071616
# 15     0.484534  0.330325  0.852037  0.486742  0.072291
# ...

# %%
result.to_csv(r'normalizedmatrix.csv')

# %%
one = result['1']
one.plot()
two = result['2']
two.plot()
three = result['3']
three.plot()
four = result['4']
four.plot()
five = result['5']
five.plot()
